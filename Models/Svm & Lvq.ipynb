# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
import pandas as pd
df = pd.read_csv('https://archive.ics.uci.edu/ml/machine-learning-databases/00476/buddymove_holidayiq.csv')
print(df)
df.shape
features=['Picnic','Religious','Nature','Theatre','Shopping']
X=df[features]
Y=df.Sports
X_train,X_test,Y_train,Y_test=train_test_split(X,Y,test_size=0.30)
from sklearn import datasets
from sklearn.metrics import accuracy_score
from sklearn import svm
from sklearn import metrics
clf = svm.SVC(kernel='linear')
clf = clf.fit(X_train, Y_train)
o1=clf.predict(X_test)
accuracy_score(o1,Y_test)
o2=clf.predict(X_train)
accuracy_score(o2,Y_train)
support_vector_indices = clf.support_
print(support_vector_indices)
# Out:
#       User Id  Sports  Religious  Nature  Theatre  Shopping  Picnic
# 0      User 1       2         77      79       69        68      95
# 1      User 2       2         62      76       76        69      68
# 2      User 3       2         50      97       87        50      75
# 3      User 4       2         68      77       95        76      61
# 4      User 5       2         98      54       59        95      86
# ..        ...     ...        ...     ...      ...       ...     ...
# 244  User 245      18        139     148      129       129     168
# 245  User 246      22        114     228      104        84     168
# 246  User 247      20        124     178      104       158     174
# 247  User 248      20        133     149      139       144     213
# 248  User 249      20        143     149      139       159     143
#
# [249 rows x 7 columns]
# [ 18  56 112   4  75  82  83  94 153 161  22  30  58  68  81 109 124 133
#  140 143   3  25  35  49  57  69 128 141 149 163  23  70  88  98 119 123
#  125 142 144  10  17  20  27  38  52  66  95  99 150 152  39  59  79 127
#    1  11  14  19  24  32  45  54  76  80 114 129 131 157 160  15  28  41
#   43  46  60  62  72 104 115 148 159 169  84 136 147   2  16  29  53  77
#   85  93  96 105 145 146 154 156  33  50  55 107 111 117 137 138 166 171
#    5   8  34  47  64  65  90 102 106 108 120 130 164 172  12  26  42  89
#  132 135]

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
import pandas as pd
data= pd.read_csv('https://archive.ics.uci.edu/ml/machine-learning-databases/00476/buddymove_holidayiq.csv')
print(data)
data.shape
features=['Picnic','Religious','Nature','Theatre','Shopping']
X=data[features]
Y=data.Sports
X_train,X_test,Y_train,Y_test=train_test_split(X,Y,test_size=0.30)


import numpy as np
dataset=np.array(data)
X=dataset[:,2:] #data
Y=dataset[:,1] #target
w1=np.random.ranf(5,) #initialising random weights 
w2=np.random.ranf(5,)
lr = 0.5

def distance(x,w):
  return(np.sqrt(np.sum((x-w)**2)))

def update_w1(x,w,lr):    # if Target=0
  return (w+lr*(x-w))

def update_w2(x,w,lr):    #if Target=1
  return (w-lr*(x-w))

for i in range(1):
  print("Iteration: ",i+1)
  for j in range(249):
    print("Input:", X[j])
    print("Target", Y[j])
    d1=distance(X[j],w1)
    d2=distance(X[j],w2)
    if d1<=d2:
      if Y[j]==0:
        w1=update_w1(X[j],w1,lr)
      else:
        w1=update_w2(X[j],w1,lr)
    else:
      if Y[j]==1:
        w2=update_w1(X[j],w2,lr)
      else:
        w2=update_w2(X[j],w2,lr)   
  lr=lr*0.8
print("Updated lr:",lr)


#Checking the classification

Sample = [ 35, 99, 201, 190, 195] 
dis1=distance(Sample,w1)
dis2=distance(Sample,w2)
if(dis1>dis2):
  print("Sample belongs to Class 1")
else:
  print("Sample belongs to Class 2")
# Out:
#       User Id  Sports  Religious  Nature  Theatre  Shopping  Picnic
# 0      User 1       2         77      79       69        68      95
# 1      User 2       2         62      76       76        69      68
# 2      User 3       2         50      97       87        50      75
# 3      User 4       2         68      77       95        76      61
# 4      User 5       2         98      54       59        95      86
# ..        ...     ...        ...     ...      ...       ...     ...
# 244  User 245      18        139     148      129       129     168
# 245  User 246      22        114     228      104        84     168
# 246  User 247      20        124     178      104       158     174
# 247  User 248      20        133     149      139       144     213
# 248  User 249      20        143     149      139       159     143
#
# [249 rows x 7 columns]
# Iteration:  1
# Input: [77 79 69 68 95]
# Target 2
# Input: [62 76 76 69 68]
# Target 2
# Input: [50 97 87 50 75]
# Target 2
# Input: [68 77 95 76 61]
# Target 2
# Input: [98 54 59 95 86]
# Target 2
# Input: [52 109 93 52 76]
# Target 3
# Input: [64 85 82 73 69]
# Target 3
# Input: [54 107 92 54 76]
# Target 3
# Input: [64 108 64 54 93]
# Target 3
# Input: [86 76 74 74 103]
# Target 3
# Input: [107 54 64 103 94]
# Target 3
# Input: [103 60 63 102 93]
# Target 3
# Input: [64 82 82 75 69]
# Target 3
# Input: [93 54 74 103 69]
# Target 3
# Input: [63 82 81 78 69]
# Target 3
# Input: [82 79 75 75 82]
# Target 3
# Input: [59 131 103 54 86]
# Target 5
# Input: [56 124 108 56 85]
# Target 5
# Input: [85 67 111 65 72]
# Target 4
# Input: [114 83 65 114 102]
# Target 5
# Input: [93 82 79 79 90]
# Target 4
# Input: [105 52 75 113 78]
# Target 4
# Input: [69 118 74 66 101]
# Target 5
# Input: [71 123 64 59 102]
# Target 4
# Input: [88 94 81 79 91]
# Target 5
# Input: [83 99 89 74 91]
# Target 5
# Input: [69 133 74 54 101]
# Target 5
# Input: [128 53 74 117 105]
# Target 5
# Input: [74 123 69 61 101]
# Target 5
# Input: [79 93 118 90 72]
# Target 5
# Input: [51 115 110 51 84]
# Target 4
# Input: [69 93 93 81 79]
# Target 5
# Input: [100 53 86 112 78]
# Target 4
# Input: [88 69 108 71 77]
# Target 4
# Input: [93 84 75 84 112]
# Target 4
# Input: [79 86 110 93 73]
# Target 4
# Input: [87 72 112 63 71]
# Target 4
# Input: [65 128 79 56 101]
# Target 5
# Input: [91 66 110 69 71]
# Target 4
# Input: [93 79 74 92 90]
# Target 4
# Input: [59 118 108 63 85]
# Target 5
# Input: [65 103 90 80 79]
# Target 5
# Input: [87 89 76 89 111]
# Target 4
# Input: [93 85 79 85 91]
# Target 4
# Input: [93 94 79 79 113]
# Target 5
# Input: [74 130 74 53 101]
# Target 5
# Input: [118 59 69 119 97]
# Target 4
# Input: [101 61 76 113 78]
# Target 4
# Input: [88 99 79 83 114]
# Target 5
# Input: [74 87 87 79 79]
# Target 4
# Input: [148 59 104 208 119]
# Target 14
# Input: [93 89 74 89 93]
# Target 5
# Input: [79 103 68 103 85]
# Target 4
# Input: [76 92 111 90 71]
# Target 4
# Input: [94 140 89 118 92]
# Target 8
# Input: [108 109 89 89 143]
# Target 8
# Input: [98 89 133 79 79]
# Target 6
# Input: [84 118 102 94 90]
# Target 8
# Input: [138 74 79 143 118]
# Target 8
# Input: [74 109 103 89 88]
# Target 6
# Input: [118 104 94 94 118]
# Target 8
# Input: [94 128 89 128 99]
# Target 8
# Input: [64 155 118 64 97]
# Target 8
# Input: [84 108 138 103 79]
# Target 6
# Input: [108 109 94 99 138]
# Target 8
# Input: [89 108 128 116 81]
# Target 6
# Input: [103 79 148 74 79]
# Target 6
# Input: [103 109 99 89 108]
# Target 6
# Input: [108 99 94 94 138]
# Target 8
# Input: [108 109 104 79 133]
# Target 8
# Input: [138 59 84 138 128]
# Target 8
# Input: [79 143 113 69 109]
# Target 8
# Input: [84 153 79 64 113]
# Target 8
# Input: [74 148 118 64 104]
# Target 8
# Input: [74 153 118 59 99]
# Target 8
# Input: [118 64 101 133 92]
# Target 6
# Input: [69 153 113 59 99]
# Target 6
# Input: [123 68 89 128 90]
# Target 6
# Input: [99 104 128 64 78]
# Target 6
# Input: [124 59 84 143 88]
# Target 6
# Input: [84 131 128 93 81]
# Target 6
# Input: [113 64 89 141 86]
# Target 6
# Input: [118 64 99 134 88]
# Target 6
# Input: [89 143 84 64 118]
# Target 8
# Input: [98 89 133 69 79]
# Target 6
# Input: [98 104 109 91 101]
# Target 6
# Input: [84 143 74 74 133]
# Target 8
# Input: [123 64 93 148 90]
# Target 8
# Input: [84 113 141 98 81]
# Target 6
# Input: [59 148 125 59 97]
# Target 6
# Input: [143 69 79 143 123]
# Target 8
# Input: [94 133 84 125 97]
# Target 8
# Input: [84 108 113 93 90]
# Target 8
# Input: [84 138 89 69 123]
# Target 8
# Input: [84 108 133 98 81]
# Target 6
# Input: [99 84 138 69 83]
# Target 6
# Input: [113 94 84 109 128]
# Target 8
# Input: [148 64 74 138 128]
# Target 6
# Input: [84 138 113 64 114]
# Target 8
# Input: [98 79 138 79 79]
# Target 6
# Input: [133 84 84 133 118]
# Target 8
# Input: [79 113 106 87 88]
# Target 6
# Input: [113 104 84 94 148]
# Target 8
# Input: [69 138 113 79 99]
# Target 6
# Input: [83 103 98 99 90]
# Target 6
# Input: [69 143 123 71 97]
# Target 8
# Input: [118 94 99 99 143]
# Target 8
# Input: [74 133 99 74 113]
# Target 6
# Input: [115 94 163 109 92]
# Target 12
# Input: [123 124 109 114 168]
# Target 12
# Input: [94 133 157 133 95]
# Target 12
# Input: [104 123 163 128 89]
# Target 12
# Input: [99 198 89 74 153]
# Target 14
# Input: [113 148 99 148 110]
# Target 14
# Input: [94 163 99 94 153]
# Target 14
# Input: [133 104 119 129 133]
# Target 12
# Input: [163 69 94 188 143]
# Target 14
# Input: [74 158 158 74 119]
# Target 12
# Input: [123 124 109 129 143]
# Target 12
# Input: [94 137 148 113 100]
# Target 12
# Input: [123 129 139 99 143]
# Target 12
# Input: [89 163 99 79 143]
# Target 12
# Input: [81 173 143 79 122]
# Target 14
# Input: [135 84 158 139 92]
# Target 14
# Input: [108 113 133 114 100]
# Target 12
# Input: [138 119 119 124 158]
# Target 14
# Input: [128 122 134 109 120]
# Target 12
# Input: [79 203 153 69 119]
# Target 14
# Input: [84 150 128 104 102]
# Target 12
# Input: [148 69 104 173 138]
# Target 12
# Input: [133 124 119 124 168]
# Target 14
# Input: [89 128 148 111 102]
# Target 12
# Input: [79 183 133 70 113]
# Target 12
# Input: [96 113 113 99 97]
# Target 12
# Input: [84 161 153 84 116]
# Target 14
# Input: [109 135 158 123 92]
# Target 12
# Input: [133 74 114 175 102]
# Target 12
# Input: [133 139 124 109 128]
# Target 14
# Input: [128 124 114 111 126]
# Target 12
# Input: [97 123 108 119 111]
# Target 10
# Input: [123 104 104 134 153]
# Target 12
# Input: [113 89 168 89 89]
# Target 10
# Input: [109 148 94 133 119]
# Target 12
# Input: [165 64 94 173 97]
# Target 10
# Input: [93 123 123 124 100]
# Target 12
# Input: [143 98 119 163 105]
# Target 14
# Input: [89 158 89 89 158]
# Target 12
# Input: [113 111 153 84 97]
# Target 10
# Input: [138 86 114 158 102]
# Target 12
# Input: [79 158 148 69 119]
# Target 12
# Input: [84 178 138 87 116]
# Target 14
# Input: [84 168 148 80 113]
# Target 14
# Input: [84 173 143 69 110]
# Target 14
# Input: [104 130 178 118 92]
# Target 12
# Input: [99 123 153 128 103]
# Target 10
# Input: [93 128 118 119 100]
# Target 12
# Input: [128 119 104 119 173]
# Target 12
# Input: [94 178 109 69 143]
# Target 14
# Input: [148 69 104 168 114]
# Target 12
# Input: [113 114 109 119 143]
# Target 12
# Input: [153 74 94 163 158]
# Target 12
# Input: [139 163 114 203 139]
# Target 22
# Input: [163 99 94 158 143]
# Target 14
# Input: [89 178 89 79 153]
# Target 12
# Input: [79 183 104 69 148]
# Target 12
# Input: [168 69 84 198 133]
# Target 12
# Input: [128 158 183 158 130]
# Target 22
# Input: [129 188 109 104 198]
# Target 22
# Input: [178 74 114 198 129]
# Target 16
# Input: [143 139 139 139 148]
# Target 20
# Input: [114 198 124 114 153]
# Target 20
# Input: [105 158 143 129 133]
# Target 18
# Input: [120 193 104 148 138]
# Target 20
# Input: [98 193 163 99 140]
# Target 20
# Input: [148 174 129 129 153]
# Target 22
# Input: [183 104 164 193 153]
# Target 20
# Input: [99 203 129 94 158]
# Target 18
# Input: [139 178 139 163 144]
# Target 22
# Input: [90 188 163 109 138]
# Target 22
# Input: [163 84 129 193 139]
# Target 18
# Input: [88 178 178 89 140]
# Target 18
# Input: [114 144 213 133 128]
# Target 18
# Input: [143 124 208 134 124]
# Target 22
# Input: [188 94 104 208 158]
# Target 20
# Input: [99 228 104 84 163]
# Target 18
# Input: [178 94 114 188 173]
# Target 18
# Input: [119 198 149 114 168]
# Target 22
# Input: [114 203 109 84 158]
# Target 20
# Input: [99 193 158 99 144]
# Target 18
# Input: [153 139 154 154 183]
# Target 22
# Input: [162 94 144 198 135]
# Target 20
# Input: [132 149 139 119 144]
# Target 18
# Input: [104 193 114 99 173]
# Target 18
# Input: [99 183 128 114 129]
# Target 18
# Input: [178 89 154 198 183]
# Target 20
# Input: [114 243 104 79 173]
# Target 20
# Input: [133 183 114 183 140]
# Target 22
# Input: [148 149 154 149 148]
# Target 22
# Input: [114 213 129 94 178]
# Target 22
# Input: [188 124 114 183 188]
# Target 22
# Input: [153 159 129 139 218]
# Target 25
# Input: [114 153 178 138 124]
# Target 18
# Input: [184 84 129 233 133]
# Target 22
# Input: [84 193 188 80 138]
# Target 18
# Input: [178 129 104 183 163]
# Target 18
# Input: [114 163 163 148 124]
# Target 18
# Input: [132 94 178 109 120]
# Target 16
# Input: [93 183 178 89 140]
# Target 20
# Input: [137 104 173 109 130]
# Target 16
# Input: [153 74 114 188 129]
# Target 18
# Input: [128 114 168 124 124]
# Target 18
# Input: [114 228 119 99 168]
# Target 22
# Input: [178 89 114 203 139]
# Target 22
# Input: [173 84 99 193 158]
# Target 18
# Input: [168 89 124 183 129]
# Target 20
# Input: [83 198 163 84 140]
# Target 18
# Input: [144 173 134 173 149]
# Target 22
# Input: [198 64 89 203 153]
# Target 18
# Input: [114 208 114 119 168]
# Target 20
# Input: [114 183 114 109 178]
# Target 18
# Input: [114 173 183 128 124]
# Target 18
# Input: [128 134 188 89 124]
# Target 18
# Input: [143 154 129 129 178]
# Target 18
# Input: [128 163 173 133 130]
# Target 18
# Input: [148 99 139 168 129]
# Target 18
# Input: [83 218 163 74 140]
# Target 18
# Input: [120 168 158 144 133]
# Target 22
# Input: [203 99 104 223 173]
# Target 22
# Input: [143 139 119 139 203]
# Target 18
# Input: [153 144 139 144 193]
# Target 22
# Input: [147 144 129 149 144]
# Target 18
# Input: [188 74 109 213 168]
# Target 18
# Input: [158 154 154 154 153]
# Target 25
# Input: [104 208 168 134 144]
# Target 25
# Input: [139 153 193 158 134]
# Target 25
# Input: [84 247 168 109 140]
# Target 25
# Input: [173 89 124 233 158]
# Target 25
# Input: [93 119 99 89 138]
# Target 8
# Input: [124 168 208 148 124]
# Target 22
# Input: [114 158 178 158 124]
# Target 18
# Input: [188 94 94 223 153]
# Target 20
# Input: [114 238 124 104 178]
# Target 25
# Input: [94 188 148 99 139]
# Target 18
# Input: [129 318 94 89 188]
# Target 25
# Input: [139 148 129 129 168]
# Target 18
# Input: [114 228 104 84 168]
# Target 22
# Input: [124 178 104 158 174]
# Target 20
# Input: [133 149 139 144 213]
# Target 20
# Input: [143 149 139 159 143]
# Target 20
# Updated lr: 0.4
# Sample belongs to Class 1
